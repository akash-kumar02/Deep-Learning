# %%
import tensorflow as tf
from tensorflow.keras.datasets import imdb
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, SimpleRNN, Dense

# %%
# load dataset
vocab_size = 10000 # top 10000 words
max_len = 200      # max review lemgth
(X_train, y_train), (X_test, y_test) = imdb.load_data(num_words=vocab_size)

# %%
# pad seq to ensure equal length
X_train = pad_sequences(X_train, maxlen=max_len)
X_test = pad_sequences(X_test, maxlen=max_len)

# %%
# create RNN model
model = Sequential()
model.add(Embedding(vocab_size, 32,input_length = max_len)) # word embeddings
model.add(SimpleRNN(64))
model.add(Dense(1, activation='sigmoid'))

# %%
# compile model
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
# train model
model.fit(X_train, y_train, epochs=5, batch_size=64,validation_split=0.2)
# Out:
# Epoch 1/5
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 20s 59ms/step - accuracy: 0.5985 - loss: 0.6493 - val_accuracy: 0.6722 - val_loss: 0.6001
# Epoch 2/5
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 19s 55ms/step - accuracy: 0.8112 - loss: 0.4283 - val_accuracy: 0.7538 - val_loss: 0.5086
# Epoch 3/5
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 19s 62ms/step - accuracy: 0.9034 - loss: 0.2403 - val_accuracy: 0.8130 - val_loss: 0.4748
# Epoch 4/5
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 17s 55ms/step - accuracy: 0.9681 - loss: 0.0941 - val_accuracy: 0.7962 - val_loss: 0.5665
# Epoch 5/5
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 17s 55ms/step - accuracy: 0.9912 - loss: 0.0312 - val_accuracy: 0.8128 - val_loss: 0.6297

# %%
# Evaluate
test_loss, test_acc = model.evaluate(X_test, y_test)
print('Test accuracy:', test_acc)
# Out:
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 9s 12ms/step - accuracy: 0.8065 - loss: 0.6478
# Test accuracy: 0.8064799904823303
